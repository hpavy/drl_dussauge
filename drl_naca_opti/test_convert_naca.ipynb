# %%
from convert_naca import *

# %%
naca_profile = ["0009", "0024", "1408", "2410", "2412", "2414", "2415", "2421", "4412", "6412"]
naca_profile_coord = dict()

# %%
for profile in naca_profile : 
    naca_profile_coord[profile] = convert_naca_profile("naca/naca_"+profile+".txt", title=f"Naca {profile}")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.076216
#          Iterations: 16
#          Function evaluations: 5522
# Optimization terminated successfully.
#          Current function value: 0.341762
#          Iterations: 12
#          Function evaluations: 4452
# Optimization terminated successfully.
#          Current function value: 0.115881
#          Iterations: 18
#          Function evaluations: 6665
# Optimization terminated successfully.
#          Current function value: 0.146046
#          Iterations: 14
#          Function evaluations: 5077
# Optimization terminated successfully.
#          Current function value: 0.062555
#          Iterations: 12
#          Function evaluations: 4412
# Optimization terminated successfully.
#          Current function value: 0.110246
#          Iterations: 12
#          Function evaluations: 4432
# Optimization terminated successfully.
#          Current function value: 0.215144
#          Iterations: 12
# ...

# %% [markdown]
#  ## Test avec code avec courbure

# %%
naca_profile_coord_curb = dict()
for profile in naca_profile : 
    naca_profile_coord_curb[profile] = convert_naca_profile_curb("naca/naca_"+profile+".txt", title=f"Naca {profile}")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.075515
#          Iterations: 19
#          Function evaluations: 8044
# Optimization terminated successfully.
#          Current function value: 0.351273
#          Iterations: 12
#          Function evaluations: 5401
# Optimization terminated successfully.
#          Current function value: 0.114368
#          Iterations: 18
#          Function evaluations: 8279
# Optimization terminated successfully.
#          Current function value: 0.145097
#          Iterations: 8
#          Function evaluations: 3417
# Optimization terminated successfully.
#          Current function value: 0.064882
#          Iterations: 7
#          Function evaluations: 2999
# Optimization terminated successfully.
#          Current function value: 0.107676
#          Iterations: 12
#          Function evaluations: 5337
# Optimization terminated successfully.
#          Current function value: 0.216956
#          Iterations: 10
# ...

# %%
naca_profile_coord
# Out:
# {}

# %%
naca_profile_coord_curb['6412']
# Out:
# array([ 0.02340366,  0.08213517,  0.12281425,  0.12498064,  0.08461117,
#        -0.01325784,  0.00811609,  0.02124909,  0.67690661, -0.0171881 ])

# %%
class test:
    def __init__(self):
        self.try = 3
        self.a = 2 + self.add(3)
    def add(self, nb):
        return nb

# %%
t = test

# %%
t.a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 t.a
#
# AttributeError: type object 'test' has no attribute 'a'
